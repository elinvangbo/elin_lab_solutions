# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd

# %%
help(create_engine)
# Out:
# Help on function create_engine in module sqlalchemy.engine:
#
# create_engine(*args, **kwargs)
#     Create a new :class:`.Engine` instance.
#
#     The standard calling form is to send the URL as the
#     first positional argument, usually a string
#     that indicates database dialect and connection arguments::
#
#
#         engine = create_engine("postgresql://scott:tiger@localhost/test")
#
#     Additional keyword arguments may then follow it which
#     establish various options on the resulting :class:`.Engine`
#     and its underlying :class:`.Dialect` and :class:`.Pool`
#     constructs::
#
#         engine = create_engine("mysql://scott:tiger@hostname/dbname",
#                                     encoding='latin1', echo=True)
#
#     The string form of the URL is
#     ``dialect[+driver]://user:password@host/dbname[?key=value..]``, where
#     ``dialect`` is a database name such as ``mysql``, ``oracle``,
# ...

# %%
connection_string = "mysql+pymysql://root:" + password + "@localhost/sakila"

# %%
import getpass
password = getpass.getpass()
# Out:
# ········

# %%
engine = create_engine(connection_string)

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila)

# %%
pd.read_sql("SELECT * FROM rental WHERE MONTH(rental_date) = 05", engine)
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 0             1 2005-05-24 22:53:30           367          130
# 1             2 2005-05-24 22:54:33          1525          459
# 2             3 2005-05-24 23:03:39          1711          408
# 3             4 2005-05-24 23:04:41          2452          333
# 4             5 2005-05-24 23:05:21          2079          222
# ...         ...                 ...           ...          ...
# 1151       1153 2005-05-31 21:36:44          2725          506
# 1152       1154 2005-05-31 21:42:09          2732           59
# 1153       1155 2005-05-31 22:17:11          2048          251
# 1154       1156 2005-05-31 22:37:34           460          106
# 1155       1157 2005-05-31 22:47:45          1449           61
#
#              return_date  staff_id         last_update
# 0    2005-05-26 22:04:30         1 2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1 2006-02-15 21:30:53
# ...

# %%
#create table
engine.execute("CREATE TABLE rentals_may AS SELECT * FROM rental WHERE MONTH(rental_date) = 05")

# %%
pd.read_sql("SELECT * FROM rentals_may", engine)
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 0             1 2005-05-24 22:53:30           367          130
# 1             2 2005-05-24 22:54:33          1525          459
# 2             3 2005-05-24 23:03:39          1711          408
# 3             4 2005-05-24 23:04:41          2452          333
# 4             5 2005-05-24 23:05:21          2079          222
# ...         ...                 ...           ...          ...
# 1151       1153 2005-05-31 21:36:44          2725          506
# 1152       1154 2005-05-31 21:42:09          2732           59
# 1153       1155 2005-05-31 22:17:11          2048          251
# 1154       1156 2005-05-31 22:37:34           460          106
# 1155       1157 2005-05-31 22:47:45          1449           61
#
#              return_date  staff_id         last_update
# 0    2005-05-26 22:04:30         1 2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1 2006-02-15 21:30:53
# ...

# %%
engine.execute("CREATE TABLE rentals_june AS SELECT * FROM rental WHERE MONTH(rental_date) = 06")

# %%
pd.read_sql("SELECT * FROM rentals_june", engine)
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 0          1158 2005-06-14 22:53:33          1632          416
# 1          1159 2005-06-14 22:55:13          4395          516
# 2          1160 2005-06-14 23:00:34          2795          239
# 3          1161 2005-06-14 23:07:08          1690          285
# 4          1162 2005-06-14 23:09:38           987          310
# ...         ...                 ...           ...          ...
# 2306       3465 2005-06-21 22:10:01          1488          510
# 2307       3466 2005-06-21 22:13:33           371          226
# 2308       3467 2005-06-21 22:19:25           729          543
# 2309       3468 2005-06-21 22:43:45          2899          100
# 2310       3469 2005-06-21 22:48:59          4087          181
#
#              return_date  staff_id         last_update
# 0    2005-06-18 21:37:33         2 2006-02-15 21:30:53
# 1    2005-06-17 02:11:13         1 2006-02-15 21:30:53
# ...

# %%
#Check the number of rentals for each customer for May.

pd.read_sql("SELECT customer_id, COUNT(rental_id) AS films_rented FROM rentals_may GROUP BY customer_id", engine)
# Out:
#      customer_id  films_rented
# 0            130             2
# 1            459             1
# 2            408             3
# 3            333             1
# 4            222             5
# ..           ...           ...
# 515          191             2
# 516          351             1
# 517           10             1
# 518          136             1
# 519           61             1
#
# [520 rows x 2 columns]

# %%
pd.read_sql("SELECT customer_id, COUNT(rental_id) AS films_rented FROM rentals_june GROUP BY customer_id", engine)
# Out:
#      customer_id  films_rented
# 0            416             5
# 1            516             6
# 2            239             5
# 3            285             3
# 4            310             6
# ..           ...           ...
# 585          412             1
# 586          335             1
# 587          226             2
# 588           22             1
# 589          126             1
#
# [590 rows x 2 columns]

# %%
rentals_may = pd.read_sql("SELECT * FROM rentals_may", engine)

# %%
rentals_june = pd.read_sql("SELECT * FROM rentals_june", engine)

# %%
rentals_may
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 0             1 2005-05-24 22:53:30           367          130
# 1             2 2005-05-24 22:54:33          1525          459
# 2             3 2005-05-24 23:03:39          1711          408
# 3             4 2005-05-24 23:04:41          2452          333
# 4             5 2005-05-24 23:05:21          2079          222
# ...         ...                 ...           ...          ...
# 1151       1153 2005-05-31 21:36:44          2725          506
# 1152       1154 2005-05-31 21:42:09          2732           59
# 1153       1155 2005-05-31 22:17:11          2048          251
# 1154       1156 2005-05-31 22:37:34           460          106
# 1155       1157 2005-05-31 22:47:45          1449           61
#
#              return_date  staff_id         last_update
# 0    2005-05-26 22:04:30         1 2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1 2006-02-15 21:30:53
# ...

# %%
films_rented_may = pd.read_sql("SELECT customer_id, COUNT(rental_id) AS films_rented_may FROM rentals_may GROUP BY customer_id", engine)

# %%
films_rented_june = pd.read_sql("SELECT customer_id, COUNT(rental_id) AS films_rented_june FROM rentals_june GROUP BY customer_id", engine)

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how: str = 'inner', on=None, left_on=None, right_on=None, left_index: bool = False, right_index: bool = False, sort: bool = False, suffixes=('_x', '_y'), copy: bool = True, indicator: bool = False, validate=None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
# ...

# %%
file = pd.merge(films_rented_may, films_rented_june, on = "customer_id")

# %%
file
# Out:
#      customer_id  films_rented_may  films_rented_june
# 0            130                 2                  6
# 1            459                 1                  7
# 2            408                 3                  3
# 3            333                 1                  4
# 4            222                 5                  2
# ..           ...               ...                ...
# 507          431                 1                  7
# 508          191                 2                  6
# 509          351                 1                  3
# 510           10                 1                  5
# 511          136                 1                  1
#
# [512 rows x 3 columns]

# %%
import numpy as np

# %%
conditions = [
    (file["films_rented_may"] > file["films_rented_june"]),
    (file["films_rented_may"] < file["films_rented_june"]),
    (file["films_rented_may"] == file["films_rented_june"])]

# %%
values = ["May", "June", "Same in May and June"]

# %%
file["Month with most rentals"] = np.select(conditions, values)

# %%
file
# Out:
#      customer_id  films_rented_may  films_rented_june Month with most rentals
# 0            130                 2                  6                    June
# 1            459                 1                  7                    June
# 2            408                 3                  3    Same in May and June
# 3            333                 1                  4                    June
# 4            222                 5                  2                     May
# ..           ...               ...                ...                     ...
# 507          431                 1                  7                    June
# 508          191                 2                  6                    June
# 509          351                 1                  3                    June
# 510           10                 1                  5                    June
# 511          136                 1                  1    Same in May and June
#
# [512 rows x 4 columns]
