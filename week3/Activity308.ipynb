# %%
#With pd.read_sql_query, you can also use the database url connection string instead of the engine. Try it.

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input
password = getpass.getpass()
db_url = f'mysql+pymysql://root:{password}@localhost/bank'
# Out:
# ········

# %%
pd.read_sql_query("SELECT * FROM loan", db_url)
# Out:
#      loan_id  account_id    date  amount  duration  payments status  \
# 0       5314        1787  930705   96396        12    8033.0      B
# 1       5316        1801  930711  165960        36    4610.0      A
# 2       6863        9188  930728  127080        60    2118.0      A
# 3       5325        1843  930803  105804        36    2939.0      A
# 4       7240       11013  930906  274740        60    4579.0      A
# ..       ...         ...     ...     ...       ...       ...    ...
# 678     5221        1284  981205   52512        12    4376.0      C
# 679     6402        6922  981206  139488        24    5812.0      C
# 680     5346        1928  981206   55632        24    2318.0      C
# 681     6748        8645  981208  240900        60    4015.0      C
# 682     8000     8000000  930705   96396        12    8033.0      C
#
#     status_desc
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ..          ...
# 678        None
# ...

# %% [markdown]
# ###### Also, pd.read_sql_table will accept a table name and will retrieve the whole table. The pd.read_sql is a convenient wrapper around both functions. Explore those functions on the table district.

# %%
pd.read_sql_table("district", db_url)
# Out:
#     A1               A2               A3       A4  A5  A6  A7  A8  A9    A10  \
# 0    1      Hl.m. Praha           Prague  1204953   0   0   0   1   1  100.0
# 1    2          Benesov  central Bohemia    88884  80  26   6   2   5   46.7
# 2    3           Beroun  central Bohemia    75232  55  26   4   1   5   41.7
# 3    4           Kladno  central Bohemia   149893  63  29   6   2   6   67.4
# 4    5            Kolin  central Bohemia    95616  65  30   4   1   6   51.4
# ..  ..              ...              ...      ...  ..  ..  ..  ..  ..    ...
# 72  73            Opava    north Moravia   182027  17  49  12   2   7   56.4
# 73  74  Ostrava - mesto    north Moravia   323870   0   0   0   1   1  100.0
# 74  75           Prerov    north Moravia   138032  67  30   4   2   5   64.6
# 75  76          Sumperk    north Moravia   127369  31  32  13   2   7   51.2
# 76  77           Vsetin    north Moravia   148545   8  35  12   3   4   53.5
#
#       A11   A12   A13  A14    A15    A16
# ...

# %% [markdown]
# Explore values in columns TYPE and OPERATION. How many different loans of each type and operation are there? How many loans for each combination? (You may want to check out pandas.crosstab function.)

# %%
data = pd.read_sql_table("trans", db_url)

# %%
data.dtypes
# Out:
# trans_id        int64
# account_id      int64
# date            int64
# type           object
# operation      object
# amount        float64
# balance       float64
# k_symbol       object
# bank           object
# account         int64
# dtype: object

# %%
data.corr()
# Out:
#             trans_id  account_id      date    amount   balance   account
# trans_id    1.000000    0.461135 -0.003756 -0.189946  0.011609 -0.203010
# account_id  0.461135    1.000000  0.000098  0.101072  0.129086 -0.035069
# date       -0.003756    0.000098  1.000000 -0.008676  0.079790  0.019903
# amount     -0.189946    0.101072 -0.008676  1.000000  0.443362  0.000413
# balance     0.011609    0.129086  0.079790  0.443362  1.000000 -0.049358
# account    -0.203010   -0.035069  0.019903  0.000413 -0.049358  1.000000

# %%
data["type"].value_counts()
# Out:
# VYDAJ     513977
# PRIJEM    339950
# VYBER      14092
# Name: type, dtype: int64

# %%
data["operation"].value_counts()
# Out:
# VYBER             391903
#                   183112
# PREVOD NA UCET    129484
# VKLAD             115624
# PREVOD Z UCTU      41214
# VYBER KARTOU        6682
# Name: operation, dtype: int64

# %%
import imblearn
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

X, y = make_blobs(n_samples=[100, 1000], cluster_std=4, n_features=2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-8dbce0bb8edd> in <module>
# ----> 1 import imblearn
#       2 from sklearn.datasets import make_blobs
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5
#
# ModuleNotFoundError: No module named 'imblearn'
